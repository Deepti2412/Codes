# %%
import spacy
import numpy as np
import pandas as pd

# %%
pip install  https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.5/en_core_web_md-2.2.5.tar.gz
# Out:
# ...
#   Stored in directory: C:\Users\Arjit's Hardwork\AppData\Local\pip\Cache\wheels\df\94\ad\f5cf59224cea6b5686ac4fd1ad19c8a07bc026e13c36502d81
# Successfully built en-core-web-md
# Note: you may need to restart the kernel to use updated packages.

# %%
nlp=spacy.load("en_core_web_md")

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
import re
import string
import nltk

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# #  Airline Problem

# %%
import pandas as pd
import numpy as np
import tweepy,codecs
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Arjit's Hardwork\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
consumer_key="uRPrUr5EjQRfm8YsLvdHl1164"
consumer_secret="vFXDmJ7OxMey5YH749EKINsKN6GsUDfhhswC2l7wsTcBNHLZuQ"
access_token="1233741800461893632-MPrPQT6B8CPPXiAXpeuGpVHDYG364O"
access_token_secret="AVU5vQ2QoLKFeSDUls3c6c7mxIU3RkVEA94qnYILludiy"

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tweepy.API(auth)

# %%
results1 = api.search(q = '@IndiGo6E', lang = 'en', result_type = 'recent', count = 500, tweet_mode = 'extended')
results2 = api.search(q = '@lufthansa', lang = 'en', result_type = 'recent', count = 500, tweet_mode = 'extended')
results3 = api.search(q = '@MAS', lang = 'en', result_type = 'recent', count = 500, tweet_mode = 'extended')
results4 = api.search(q = '@emirates', lang = 'en', result_type = 'recent', count = 500, tweet_mode = 'extended')
r1=[]
r2=[]
r3=[]
r4=[]
for t in results1:
    if t.author.screen_name !='IndiGo6E':
        r1.append(t.full_text)
        print(t.full_text)
for t in results2:
    if t.author.screen_name !='lufthansa':
        r2.append(t.full_text)
        print(t.full_text)
for t in results3:
    if t.author.screen_name !='MAS':
        r3.append(t.full_text)
        print(t.full_text) 
for t in results4:
    if t.author.screen_name !='emirates':
        r4.append(t.full_text)
        print(t.full_text)
# Out:
# @happyeasygo know that @MoCA_GoI stopped operation of all dosmestic flights. How can I get my refund of upcoming flights(order Id 689963691990484711) on 28 March and 30 March from @flyspicejet (ZCP8RJ) &amp; @IndiGo6E (FML6MN) https://t.co/5MoTA56XZd
# Are flights getting cancelled @IndiGo6E for 24 march?
#
# I have already booked ticket🙁
# @IndiGo6E with the current closure of domestic flights..Please let me know the status of my flight.. If possible put me on a earlier flight.. I am not being able to connect to your customer care.. Pls help https://t.co/VusaRMApbJ
# @IndiGo6E My PNR is ULCRXG and I want to cancel this ticket as statewide lockdown is in place. Please let me know how much amount will be refunded.
# @IndiGo6E  Team indigo... cant reach you on phone for past 24 hrs. This is for PNR LWLZ3U - flight 6E534- IXU CCU - 8 Passengers. need cancellation with full refund . entire west bengal is in lockout mode and travelling is not possible as per Govt directives
# ...

# %%
master_results=[]
for text in r1:
    master_results.append(text)
for text in r2:
    master_results.append(text)
for text in r3:
    master_results.append(text)
for text in r4:
    master_results.append(text)

# %%
type(master_results)
# Out:
# list

# %%
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])
emoticons=emoticons_happy.union(emoticons_sad)

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)        
    return input_txt

def clean_tweets(lst):
    # remove twitter Return handles (RT @xxx:)
    lst = np.vectorize(remove_pattern)(lst, "RT @[\w]*:")
    # remove twitter handles (@xxx)
    lst = np.vectorize(remove_pattern)(lst, "@[\w]*")
    # remove URL links (httpxxx)
    lst = np.vectorize(remove_pattern)(lst, "https?://[A-Za-z0-9./]*")   
     # Remove all single characters 
    lst = np.vectorize(remove_pattern)(lst, "\s+[a-zA-Z]\s+") #space followed by alphabet, followed by space
    # remove numbers
    lst = np.vectorize(remove_pattern)(lst, "\d")
    # remove punctuations
    lst = np.vectorize(remove_pattern)(lst, "[\!\:\&\;\#\@//]")
    return lst
    lst = np.vectorize(remove_pattern)(lst, "[0-9]{2}/[0-9]{2}/[0-9]{4}")
    return lst
    lst = np.vectorize(remove_pattern)(lst, "[0-9]{2}:[0-9]{2}]")
    return lst
    lst = np.vectorize(remove_pattern)(lst, "\\r\\n|\\r|\\n")
    return lst
    lst = np.vectorize(remove_pattern)(lst, "[\-/ /+\]")
    return lst

# %%
cleantw = clean_tweets(master_results)

# %%
type(cleantw)
# Out:
# numpy.ndarray

# %%
word=[]
for words in cleantw:
    word.append(words)
print (word[0])
# Out:
#  know that  stopped operation of all dosmestic flights. How canget my refund of upcoming flights(order Id ) on  March and  March from  (ZCPRJ) amp  (FMLMN)

# %%
text=pd.Series(word).str.cat(sep=' ')

# %%
word_tokens = word_tokenize(text) 
word_tokens[0:5]
# Out:
# ['know', 'that', 'stopped', 'operation', 'of']

# %%
filtered_tokens = [w for w in word_tokens if not w in (stop_words and emoticons and string.punctuation)]

# %%
filtered_tokens[0:5]
# Out:
# ['know', 'that', 'stopped', 'operation', 'of']

# %%
patterns = r"""
  NP: {<DT|JJ|NN.*>+}          # Chunk sequences of DT, JJ, NN
  PP: {<IN><NP>}               # Chunk prepositions followed by NP
  VP: {<VB.*><NP|PP|CLAUSE>+$} # Chunk verbs and their arguments
  CLAUSE: {<NP><VP>}           # Chunk NP, VP
  """

# %%
chunkparser = nltk.RegexpParser(patterns)
tree = chunkparser.parse(nltk.pos_tag(filtered_tokens))
print(tree)
# Out:
# (S
#   know/VB
#   (NP that/DT)
#   stopped/VBD
#   (NP operation/NN)
#   (PP of/IN (NP all/DT dosmestic/JJ flights/NNS))
#   How/WRB
#   canget/VB
#   my/PRP$
#   (NP refund/NN)
#   of/IN
#   upcoming/VBG
#   (NP flights/NNS order/NN Id/NNP)
#   (PP on/IN (NP March/NNP))
#   and/CC
#   (NP March/NNP)
#   (PP from/IN (NP ZCPRJ/NNP amp/NN FMLMN/NNP Are/NNP flights/NNS))
#   getting/VBG
#   cancelled/VBN
#   (PP for/IN (NP march/NN))
#   have/VBP
#   already/RB
#   booked/VBN
#   (NP ticket🙁/NN)
#   (PP with/IN (NP the/DT current/JJ closure/NN))
#   (PP of/IN (NP domestic/JJ flights..Please/NN))
#   let/VB
#   me/PRP
#   know/VB
#   (NP the/DT status/NN)
#   of/IN
#   my/PRP$
#   (NP flight../NN)
#   (PP If/IN (NP possible/JJ))
#   put/VBD
#   me/PRP
#   onearlier/JJR
#   (NP flight..am/NN)
#   not/RB
#   being/VBG
#   (NP able/JJ)
#   to/TO
#   connect/VB
#   to/TO
#   your/PRP$
#   (NP customer/NN care../NN Pls/NNP help/NN My/NNP PNR/NNP)
#   is/VBZ
#   (NP ULCRXG/NNP andwant/NN)
# ...

# %%
tree.label
# Out:
# <bound method Tree.label of Tree('S', [('know', 'VB'), Tree('NP', [('that', 'DT')]), ('stopped', 'VBD'), Tree('NP', [('operation', 'NN')]), Tree('PP', [('of', 'IN'), Tree('NP', [('all', 'DT'), ('dosmestic', 'JJ'), ('flights', 'NNS')])]), ('How', 'WRB'), ('canget', 'VB'), ('my', 'PRP$'), Tree('NP', [('refund', 'NN')]), ('of', 'IN'), ('upcoming', 'VBG'), Tree('NP', [('flights', 'NNS'), ('order', 'NN'), ('Id', 'NNP')]), Tree('PP', [('on', 'IN'), Tree('NP', [('March', 'NNP')])]), ('and', 'CC'), Tree('NP', [('March', 'NNP')]), Tree('PP', [('from', 'IN'), Tree('NP', [('ZCPRJ', 'NNP'), ('amp', 'NN'), ('FMLMN', 'NNP'), ('Are', 'NNP'), ('flights', 'NNS')])]), ('getting', 'VBG'), ('cancelled', 'VBN'), Tree('PP', [('for', 'IN'), Tree('NP', [('march', 'NN')])]), ('have', 'VBP'), ('already', 'RB'), ('booked', 'VBN'), Tree('NP', [('ticket🙁', 'NN')]), Tree('PP', [('with', 'IN'), Tree('NP', [('the', 'DT'), ('current', 'JJ'), ('closure', 'NN')])]), Tree('PP', [('of', 'IN'), Tree('NP', [('domestic', '
# ...

# %%
tree1=tree.subtrees

# %% [markdown]
# # Creatin Subtrees of the trees

# %%
tree1
# Out:
# <bound method Tree.subtrees of Tree('S', [('know', 'VB'), Tree('NP', [('that', 'DT')]), ('stopped', 'VBD'), Tree('NP', [('operation', 'NN')]), Tree('PP', [('of', 'IN'), Tree('NP', [('all', 'DT'), ('dosmestic', 'JJ'), ('flights', 'NNS')])]), ('How', 'WRB'), ('canget', 'VB'), ('my', 'PRP$'), Tree('NP', [('refund', 'NN')]), ('of', 'IN'), ('upcoming', 'VBG'), Tree('NP', [('flights', 'NNS'), ('order', 'NN'), ('Id', 'NNP')]), Tree('PP', [('on', 'IN'), Tree('NP', [('March', 'NNP')])]), ('and', 'CC'), Tree('NP', [('March', 'NNP')]), Tree('PP', [('from', 'IN'), Tree('NP', [('ZCPRJ', 'NNP'), ('amp', 'NN'), ('FMLMN', 'NNP'), ('Are', 'NNP'), ('flights', 'NNS')])]), ('getting', 'VBG'), ('cancelled', 'VBN'), Tree('PP', [('for', 'IN'), Tree('NP', [('march', 'NN')])]), ('have', 'VBP'), ('already', 'RB'), ('booked', 'VBN'), Tree('NP', [('ticket🙁', 'NN')]), Tree('PP', [('with', 'IN'), Tree('NP', [('the', 'DT'), ('current', 'JJ'), ('closure', 'NN')])]), Tree('PP', [('of', 'IN'), Tree('NP', [('domestic'
# ...

# %%
for subtree in tree.subtrees():
    re.sub('-.*', '', subtree.label())
print (tree)
# Out:
# (S
#   know/VB
#   (NP that/DT)
#   stopped/VBD
#   (NP operation/NN)
#   (PP of/IN (NP all/DT dosmestic/JJ flights/NNS))
#   How/WRB
#   canget/VB
#   my/PRP$
#   (NP refund/NN)
#   of/IN
#   upcoming/VBG
#   (NP flights/NNS order/NN Id/NNP)
#   (PP on/IN (NP March/NNP))
#   and/CC
#   (NP March/NNP)
#   (PP from/IN (NP ZCPRJ/NNP amp/NN FMLMN/NNP Are/NNP flights/NNS))
#   getting/VBG
#   cancelled/VBN
#   (PP for/IN (NP march/NN))
#   have/VBP
#   already/RB
#   booked/VBN
#   (NP ticket🙁/NN)
#   (PP with/IN (NP the/DT current/JJ closure/NN))
#   (PP of/IN (NP domestic/JJ flights..Please/NN))
#   let/VB
#   me/PRP
#   know/VB
#   (NP the/DT status/NN)
#   of/IN
#   my/PRP$
#   (NP flight../NN)
#   (PP If/IN (NP possible/JJ))
#   put/VBD
#   me/PRP
#   onearlier/JJR
#   (NP flight..am/NN)
#   not/RB
#   being/VBG
#   (NP able/JJ)
#   to/TO
#   connect/VB
#   to/TO
#   your/PRP$
#   (NP customer/NN care../NN Pls/NNP help/NN My/NNP PNR/NNP)
#   is/VBZ
#   (NP ULCRXG/NNP andwant/NN)
# ...

# %% [markdown]
# # Creating named entity recognition from Spacy

# %%
doc=nlp(text)

# %%
doc[:50]

# %%
df=([(X.text, X.label_,spacy.explain(X.label_)) for X in doc.ents])

# %%
df1=[]
for i in df:
    df1.append(i)

# %%
df1
